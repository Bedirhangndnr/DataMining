# %%
import pandas as pd

#https://www.google.com/covid19/mobility/
url='https://drive.google.com/file/d/18gyHbx6rfogq3yQ-GR9COjcGgyYlCnBZ/view?usp=sharing'
url2='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url2)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167657 entries, 0 to 167656
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count   Dtype
# ---  ------                                              --------------   -----
#  0   country_region_code                                 167657 non-null  object
#  1   country_region                                      167657 non-null  object
#  2   sub_region_1                                        167336 non-null  object
#  3   sub_region_2                                        141692 non-null  object
#  4   metro_area                                          0 non-null       float64
#  5   iso_3166_2_code                                     25644 non-null   object
#  6   census_fips_code                                    0 non-null       float64
#  7   place_id                                            167657 non-null  object
#  8   date                                                167657 non-null  object
#  9   retail_and_recreation_percent_change_from_baseline  101865 non-null  float64
#  10  grocery_and_pharmacy_percent_change_from_baseline   106104 non-null  float64
#  11  parks_percent_change_from_baseline                  95186 non-null   float64
#  12  transit_stations_percent_change_from_baseline       87723 non-null   float64
#  13  workplaces_percent_change_from_baseline             158870 non-null  float64
#  14  residential_percent_change_from_baseline            98651 non-null   float64
# dtypes: float64(8), object(7)
# memory usage: 19.2+ MB

# %% [markdown]
# census_fips_code  ve metro_area değişkenlerinin tamamı null olduğu içib bu iki değişkeni describe yaparken düşürelim:

# %%
df.describe()
# Out:
#        metro_area  census_fips_code  \
# count         0.0               0.0
# mean          NaN               NaN
# std           NaN               NaN
# min           NaN               NaN
# 25%           NaN               NaN
# 50%           NaN               NaN
# 75%           NaN               NaN
# max           NaN               NaN
#
#        retail_and_recreation_percent_change_from_baseline  \
# count                                      101865.000000
# mean                                          -26.758749
# std                                            30.125282
# min                                          -100.000000
# 25%                                           -44.000000
# 50%                                           -24.000000
# 75%                                            -8.000000
# max                                           333.000000
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# count                                      106104.000000
# mean                                            2.700699
# std                                            32.575277
# min                                          -100.000000
# 25%                                            -9.000000
# 50%                                             5.000000
# 75%                                            18.000000
# max                                           321.000000
#
#        parks_percent_change_from_baseline  \
# count                        95186.000000
# mean                             5.780503
# std                             53.051874
# min                           -100.000000
# 25%                            -26.000000
# 50%                              2.000000
# 75%                             30.000000
# max                            694.000000
#
#        transit_stations_percent_change_from_baseline  \
# count                                   87723.000000
# mean                                      -25.233006
# std                                        35.328635
# min                                      -100.000000
# 25%                                       -48.000000
# 50%                                       -25.000000
# 75%                                        -5.000000
# max                                       318.000000
#
#        workplaces_percent_change_from_baseline  \
# count                            158870.000000
# mean                                -19.002795
# std                                  21.563078
# min                                 -94.000000
# 25%                                 -30.000000
# 50%                                 -17.000000
# 75%                                  -6.000000
# max                                 136.000000
#
#        residential_percent_change_from_baseline
# count                              98651.000000
# mean                                   6.990188
# std                                    8.715291
# min                                  -28.000000
# 25%                                    1.000000
# 50%                                    5.000000
# 75%                                   12.000000
# max                                   50.000000

# %%
df.drop(['census_fips_code', 'metro_area'], axis=1).describe()[:][3:] #(bu değişiklik data üzerinde kalıcı olmayacak.)
# Out:
#      retail_and_recreation_percent_change_from_baseline  \
# min                                             -100.0
# 25%                                              -44.0
# 50%                                              -24.0
# 75%                                               -8.0
# max                                              333.0
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# min                                             -100.0
# 25%                                               -9.0
# 50%                                                5.0
# 75%                                               18.0
# max                                              321.0
#
#      parks_percent_change_from_baseline  \
# min                              -100.0
# 25%                               -26.0
# 50%                                 2.0
# 75%                                30.0
# max                               694.0
#
#      transit_stations_percent_change_from_baseline  \
# min                                         -100.0
# 25%                                          -48.0
# 50%                                          -25.0
# 75%                                           -5.0
# max                                          318.0
#
#      workplaces_percent_change_from_baseline  \
# min                                    -94.0
# 25%                                    -30.0
# 50%                                    -17.0
# 75%                                     -6.0
# max                                    136.0
#
#      residential_percent_change_from_baseline
# min                                     -28.0
# 25%                                       1.0
# 50%                                       5.0
# 75%                                      12.0
# max                                      50.0

# %%
#Soru2

# %%
from pandas.plotting import scatter_matrix
attributes= list(df.columns[9:15]) # 9-14 column isimleri.
scatter_matrix(df[attributes], figsize=(24, 16));

# %%
# değişken isimleri çok uzun olduğu için anlaşılması biraz zor gözüküyor. Değişken isimlerini kısaltıp tekrar çizelim. 
from pandas.plotting import scatter_matrix
df_copy=df[9:].copy()
df_copy = df_copy.rename(columns=lambda x: x[:10])
attributes= list(df_copy.columns[9:15]) # 9-14 column isimleri.
scatter_matrix(df_copy[attributes], figsize=(24, 16));

# %%
df_copy=df.copy()
df_copy.columns[9:15]
df_copy = df_copy.rename(columns=lambda x: x[:20])

# %% [markdown]
# 3. Soru Bu datadaki [9-14] sütunlarını boxplot ile çizirek hangi sütünda outlier olup olmadığını belirleyiniz.

# %%
attributes=list(df_copy.columns[9:])
df_copy.boxplot(column=attributes, figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# Out:
#              metro_area  census_fips_code  \
# mounth_date
# 02                  NaN               NaN
# 03                  NaN               NaN
# 04                  NaN               NaN
# 05                  NaN               NaN
# 06                  NaN               NaN
# 07                  NaN               NaN
# 08                  NaN               NaN
# 09                  NaN               NaN
# 10                  NaN               NaN
# 11                  NaN               NaN
# 12                  NaN               NaN
#
#              retail_and_recreation_percent_change_from_baseline  \
# mounth_date
# 02                                                    2.028130
# 03                                                  -21.700010
# 04                                                  -63.148836
# 05                                                  -55.673896
# 06                                                  -18.156210
# 07                                                   -6.876458
# 08                                                   -9.014545
# 09                                                  -13.071653
# 10                                                  -13.590351
# 11                                                  -26.801938
# 12                                                  -47.541929
#
#              grocery_and_pharmacy_percent_change_from_baseline  \
# mounth_date
# 02                                                    3.238759
# 03                                                   -4.395083
# 04                                                  -26.497847
# 05                                                  -15.239506
# 06                                                   12.410230
# 07                                                   15.260359
# 08                                                    9.800086
# 09                                                   10.092360
# 10                                                   19.569650
# 11                                                    9.294253
# 12                                                    1.021868
#
#              parks_percent_change_from_baseline  \
# mounth_date
# 02                                     4.509374
# 03                                    -6.153226
# 04                                   -42.117354
# 05                                   -28.837900
# 06                                    32.502002
# 07                                    55.750799
# 08                                    60.977582
# 09                                    38.977984
# 10                                    30.077698
# 11                                    -1.853678
# 12                                   -26.385514
#
#              transit_stations_percent_change_from_baseline  \
# mounth_date
# 02                                               -6.643751
# 03                                              -22.896115
# 04                                              -64.418867
# 05                                              -58.020520
# 06                                              -17.117761
# 07                                               -1.882360
# 08                                                1.375155
# 09                                              -11.851192
# 10                                              -10.521094
# 11                                              -25.197093
# 12                                              -39.558470
#
#              workplaces_percent_change_from_baseline  \
# mounth_date
# 02                                          9.353484
# 03                                        -12.652553
# 04                                        -47.539997
# 05                                        -41.539711
# 06                                        -10.425022
# 07                                        -10.858957
# 08                                        -16.412747
# 09                                        -11.053215
# 10                                         -8.295500
# 11                                        -14.877225
# 12                                        -30.277044
#
#              residential_percent_change_from_baseline
# mounth_date
# 02                                          -0.698443
# 03                                           6.332819
# 04                                          20.742720
# 05                                          17.455508
# 06                                           4.339668
# 07                                          -0.082189
# 08                                          -0.669343
# 09                                           2.389219
# 10                                           3.886670
# 11                                           8.382888
# 12                                          15.067144

# %%
#Soru4 

df['mounth_date'] = df['date'].apply(lambda x : x[5:7])
#df.plot(x=df.groupby("mounth_date").groups, y=df_copy.columns[9:15])

# %%
df_groupbydate=df.groupby("mounth_date")
df_g==df_groupbydate.mean()
for i in df.columns[9:15]:
    df_g[str(i)].plot(x="mounth_date", legend=True, figsize=(12,10))

# %%
df_tr_g
# Out:
#              metro_area  census_fips_code  \
# mounth_date
# 02                  NaN               NaN
# 03                  NaN               NaN
# 04                  NaN               NaN
# 05                  NaN               NaN
# 06                  NaN               NaN
# 07                  NaN               NaN
# 08                  NaN               NaN
# 09                  NaN               NaN
# 10                  NaN               NaN
# 11                  NaN               NaN
# 12                  NaN               NaN
#
#              retail_and_recreation_percent_change_from_baseline  \
# mounth_date
# 02                                                  -17.661226
# 03                                                  -15.871728
# 04                                                  -13.620913
# 05                                                  -13.275583
# 06                                                  -11.242407
# 07                                                  -10.204524
# 08                                                   -8.661306
# 09                                                   -8.070815
# 10                                                   -9.343662
# 11                                                  -12.473075
# 12                                                  -16.374227
#
#              grocery_and_pharmacy_percent_change_from_baseline  \
# mounth_date
# 02                                                   28.166500
# 03                                                   29.541779
# 04                                                   32.099813
# 05                                                   33.608236
# 06                                                   35.714954
# 07                                                   35.064666
# 08                                                   35.406221
# 09                                                   35.585521
# 10                                                   35.270040
# 11                                                   33.678385
# 12                                                   30.188013
#
#              parks_percent_change_from_baseline  \
# mounth_date
# 02                                     7.519059
# 03                                     8.863142
# 04                                    12.303381
# 05                                    14.179388
# 06                                    17.191712
# 07                                    18.772433
# 08                                    22.180223
# 09                                    20.004625
# 10                                    17.049324
# 11                                    12.602000
# 12                                     8.296779
#
#              transit_stations_percent_change_from_baseline  \
# mounth_date
# 02                                              -11.058445
# 03                                               -9.228423
# 04                                               -5.898289
# 05                                               -4.155829
# 06                                                0.078038
# 07                                               -0.055611
# 08                                               -1.048513
# 09                                               -1.471008
# 10                                               -7.232156
# 11                                               -9.094768
# 12                                              -10.253755
#
#              workplaces_percent_change_from_baseline  \
# mounth_date
# 02                                        -18.941185
# 03                                        -18.537919
# 04                                        -18.970490
# 05                                        -18.544114
# 06                                        -17.710788
# 07                                        -18.163197
# 08                                        -17.997623
# 09                                        -17.474736
# 10                                        -17.859672
# 11                                        -17.710205
# 12                                        -18.298767
#
#              residential_percent_change_from_baseline
# mounth_date
# 02                                           5.966651
# 03                                           5.702478
# 04                                           5.425341
# 05                                           5.438638
# 06                                           4.876288
# 07                                           4.574906
# 08                                           4.038553
# 09                                           4.141958
# 10                                           4.205219
# 11                                           4.798115
# 12                                           5.810877

# %%
#Soru 5
from matplotlib import pyplot as plt 

df_tr=pd.read_csv("2021_TR_Region_Mobility_Report.csv")     #tr verisini okuduk 
df_tr['mounth_date'] = df['date'].apply(lambda x : x[5:7])  # ay bilgisi seçildi
df_tr_g=df_tr.groupby("mounth_date").mean()           


ax1=0
ax2=0
x=df_tr_g.index
fig, axs = plt.subplots(2, 3,figsize=(20,13))
for i in df.columns[9:15]:
    y1=df_g[str(i)]
    y2=df_tr_g[str(i)]
    axs[ax1,ax2].plot(x,y1)
    axs[ax1,ax2].plot(x,y2)
    if(ax1==1):
        ax1=0
    else:ax1+=1
    if(ax2==2):
        ax2=0
    else: ax2+=1
